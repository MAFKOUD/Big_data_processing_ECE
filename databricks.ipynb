# %%
catalog = 'taxi_eda_db'


schema = 'yellow_taxi_trips'
volume = 'data'
file_name = 'yellow_tripdata_2019-01.parquet'
table_name = 'tbl_yellow_taxi_trips'
path_volume = '/Volumes/' + catalog + "/" + schema + '/' + volume
path_table =  catalog + "." + schema
download_url = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet'

# %%
spark.sql('create catalog if not exists ' + catalog)
spark.sql('create schema if not exists ' + catalog + '.' + schema)
spark.sql('create volume if not exists ' + catalog + '.' + schema + '.' + volume)
# Out:
# DataFrame[]

# %%
dbutils.fs.cp(f"{download_url}", f"{path_volume}" + "/" + f"{file_name}")
# Out:
# True

# %%
df_trips = spark.read.parquet(f"{path_volume}/{file_name}",
  header=True,
  inferSchema=True,
  sep=",")

# %%
df_trips.show()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       1| 2019-01-01 00:46:40|  2019-01-01 00:53:20|            1.0|          1.5|       1.0|                 N|         151|         239|           1|        7.0|  0.5|    0.5|      1.65|         0.0|                  0.3|        9.95|                NULL|       NULL|
# |       1| 2019-01-01 00:59:47|  2019-01-01 01:18:59|            1.0|          2.6|       1.0|                 N|         239|         246|           1|       14.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        16.3|                NULL|       NULL|
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|            3.0|          0.0|       1.0|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                NULL|       NULL|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                NULL|       NULL|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|
# |       2| 2018-11-28 16:25:49|  2018-11-28 16:28:26|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|        5.76|                  0.3|       13.31|                NULL|       NULL|
# |       2| 2018-11-28 16:29:37|  2018-11-28 16:33:43|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|
# |       1| 2019-01-01 00:21:28|  2019-01-01 00:28:37|            1.0|          1.3|       1.0|                 N|         163|         229|           1|        6.5|  0.5|    0.5|      1.25|         0.0|                  0.3|        9.05|                NULL|       NULL|
# |       1| 2019-01-01 00:32:01|  2019-01-01 00:45:39|            1.0|          3.7|       1.0|                 N|         229|           7|           1|       13.5|  0.5|    0.5|       3.7|         0.0|                  0.3|        18.5|                NULL|       NULL|
# |       1| 2019-01-01 00:57:32|  2019-01-01 01:09:32|            2.0|          2.1|       1.0|                 N|         141|         234|           1|       10.0|  0.5|    0.5|       1.7|         0.0|                  0.3|        13.0|                NULL|       NULL|
# |       1| 2019-01-01 00:24:04|  2019-01-01 00:47:06|            2.0|          2.8|       1.0|                 N|         246|         162|           1|       15.0|  0.5|    0.5|      3.25|         0.0|                  0.3|       19.55|                NULL|       NULL|
# |       1| 2019-01-01 00:21:59|  2019-01-01 00:28:24|            1.0|          0.7|       1.0|                 N|         238|         151|           1|        5.5|  0.5|    0.5|       1.7|         0.0|                  0.3|         8.5|                NULL|       NULL|
# |       1| 2019-01-01 00:45:21|  2019-01-01 01:31:05|            1.0|          8.7|       1.0|                 N|         163|          25|           1|       34.5|  0.5|    0.5|      7.15|         0.0|                  0.3|       42.95|                NULL|       NULL|
# |       1| 2019-01-01 00:43:19|  2019-01-01 01:07:42|            1.0|          6.3|       1.0|                 N|         224|          25|           1|       21.5|  0.5|    0.5|       5.7|         0.0|                  0.3|        28.5|                NULL|       NULL|
# |       1| 2019-01-01 00:58:24|  2019-01-01 01:15:18|            1.0|          2.7|       1.0|                 N|         141|         234|           1|       13.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        15.3|                NULL|       NULL|
# |       2| 2019-01-01 00:23:14|  2019-01-01 00:25:40|            1.0|         0.38|       1.0|                 N|         170|         170|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         4.8|                NULL|       NULL|
# |       2| 2019-01-01 00:39:51|  2019-01-01 00:48:02|            1.0|         0.55|       1.0|                 N|         170|         170|           1|        6.5|  0.5|    0.5|      1.95|         0.0|                  0.3|        9.75|                NULL|       NULL|
# |       2| 2019-01-01 00:46:00|  2019-01-01 00:49:07|            1.0|          0.3|       1.0|                 N|         107|         107|           1|        4.0|  0.5|    0.5|      1.06|         0.0|                  0.3|        6.36|                NULL|       NULL|
# |       2| 2019-01-01 00:57:45|  2019-01-01 01:03:51|            1.0|         1.42|       1.0|                 N|         170|         141|           1|        6.5|  0.5|    0.5|      1.56|         0.0|                  0.3|        9.36|                NULL|       NULL|
# |       2| 2019-01-01 00:16:16|  2019-01-01 00:25:57|            1.0|         1.72|       1.0|                 N|          41|         247|           2|        9.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        10.3|                NULL|       NULL|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# Part 1 :

# %%
from pyspark.sql.functions import monotonically_increasing_id

df_trips = df_trips.withColumn("trip_id", monotonically_increasing_id())
df_trips.show(5)
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|trip_id|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+
# |       1| 2019-01-01 00:46:40|  2019-01-01 00:53:20|            1.0|          1.5|       1.0|                 N|         151|         239|           1|        7.0|  0.5|    0.5|      1.65|         0.0|                  0.3|        9.95|                NULL|       NULL|      0|
# |       1| 2019-01-01 00:59:47|  2019-01-01 01:18:59|            1.0|          2.6|       1.0|                 N|         239|         246|           1|       14.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        16.3|                NULL|       NULL|      1|
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|            3.0|          0.0|       1.0|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                NULL|       NULL|      2|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                NULL|       NULL|      3|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|      4|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col

df_trips.orderBy(col("passenger_count").desc()).select("trip_id", "passenger_count").show(1)
# Out:
# +-------+---------------+
# |trip_id|passenger_count|
# +-------+---------------+
# | 949956|            9.0|
# +-------+---------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import avg

df_trips.select(avg("passenger_count").alias("avg_passenger_count")).show()
# Out:
# +-------------------+
# |avg_passenger_count|
# +-------------------+
# | 1.5670317144945614|
# +-------------------+

# %%
# Plus court
df_trips.orderBy(col("trip_distance").asc()).select("trip_id", "trip_distance").show(1)

# Plus long
df_trips.orderBy(col("trip_distance").desc()).select("trip_id", "trip_distance").show(1)
# Out:
# +-------+-------------+
# |trip_id|trip_distance|
# +-------+-------------+
# |      2|          0.0|
# +-------+-------------+
# only showing top 1 row
# +-------+-------------+
# |trip_id|trip_distance|
# +-------+-------------+
# |6074091|        831.8|
# +-------+-------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import unix_timestamp

df_trips = df_trips.withColumn("trip_duration",
                               (unix_timestamp("tpep_dropoff_datetime") - unix_timestamp("tpep_pickup_datetime")))

# Plus court
df_trips.orderBy(col("trip_duration").asc()).select("trip_id", "trip_duration").show(1)

# Plus long
df_trips.orderBy(col("trip_duration").desc()).select("trip_id", "trip_duration").show(1)
# Out:
# +-------+-------------+
# |trip_id|trip_duration|
# +-------+-------------+
# |1203184|     -5056830|
# +-------+-------------+
# only showing top 1 row
# +-------+-------------+
# |trip_id|trip_duration|
# +-------+-------------+
# |  68267|      2618881|
# +-------+-------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import to_date, count

df_trips = df_trips.withColumn("pickup_date", to_date("tpep_pickup_datetime"))

df_trips.groupBy("pickup_date").agg(count("*").alias("trips_per_day")) \
    .orderBy(col("trips_per_day").desc()).show(1)

df_trips.groupBy("pickup_date").agg(count("*").alias("trips_per_day")) \
    .orderBy(col("trips_per_day").asc()).show(1)
# Out:
# +-----------+-------------+
# |pickup_date|trips_per_day|
# +-----------+-------------+
# | 2019-01-25|       292499|
# +-----------+-------------+
# only showing top 1 row
# +-----------+-------------+
# |pickup_date|trips_per_day|
# +-----------+-------------+
# | 2018-12-21|            1|
# +-----------+-------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import hour

df_trips = df_trips.withColumn("pickup_hour", hour("tpep_pickup_datetime"))

df_trips.groupBy("pickup_hour").agg(count("*").alias("trips_per_hour")) \
    .orderBy(col("trips_per_hour").desc()).show(1)

df_trips.groupBy("pickup_hour").agg(count("*").alias("trips_per_hour")) \
    .orderBy(col("trips_per_hour").asc()).show(1)
# Out:
# +-----------+--------------+
# |pickup_hour|trips_per_hour|
# +-----------+--------------+
# |         18|        515390|
# +-----------+--------------+
# only showing top 1 row
# +-----------+--------------+
# |pickup_hour|trips_per_hour|
# +-----------+--------------+
# |          4|         61424|
# +-----------+--------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import dayofweek

df_trips = df_trips.withColumn("day_of_week", dayofweek("tpep_pickup_datetime"))

df_trips.groupBy("day_of_week").agg(count("*").alias("trips_per_day_of_week")) \
    .orderBy(col("trips_per_day_of_week").desc()).show(1)

df_trips.groupBy("day_of_week").agg(count("*").alias("trips_per_day_of_week")) \
    .orderBy(col("trips_per_day_of_week").asc()).show(1)
# Out:
# +-----------+---------------------+
# |day_of_week|trips_per_day_of_week|
# +-----------+---------------------+
# |          5|              1357043|
# +-----------+---------------------+
# only showing top 1 row
# +-----------+---------------------+
# |day_of_week|trips_per_day_of_week|
# +-----------+---------------------+
# |          1|               859905|
# +-----------+---------------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import corr

df_trips.select(corr("trip_distance", "tip_amount").alias("corr_distance_tip"),
                corr("passenger_count", "tip_amount").alias("corr_passenger_tip")).show()
# Out:
# +------------------+--------------------+
# | corr_distance_tip|  corr_passenger_tip|
# +------------------+--------------------+
# |0.5269200663652669|0.001084223312167...|
# +------------------+--------------------+

# %%
df_trips.orderBy(col("extra").desc()).select("trip_id", "extra").show(1)
# Out:
# +-------+------+
# |trip_id| extra|
# +-------+------+
# |5323483|535.38|
# +-------+------+
# only showing top 1 row

# %%
df_trips.filter((col("trip_duration") < 0) | (col("trip_distance") == 0) | (col("tip_amount") > 1000)).show(5)
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+-------------+-----------+-----------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|trip_id|trip_duration|pickup_date|pickup_hour|day_of_week|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+-------------+-----------+-----------+-----------+
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|            3.0|          0.0|       1.0|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                NULL|       NULL|      2|          250| 2018-12-21|         13|          6|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                NULL|       NULL|      3|          200| 2018-11-28|         15|          4|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|      4|           96| 2018-11-28|         15|          4|
# |       2| 2018-11-28 16:25:49|  2018-11-28 16:28:26|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|        5.76|                  0.3|       13.31|                NULL|       NULL|      5|          157| 2018-11-28|         16|          4|
# |       2| 2018-11-28 16:29:37|  2018-11-28 16:33:43|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|      6|          246| 2018-11-28|         16|          4|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+-------------+-----------+-----------+-----------+
# only showing top 5 rows

# %%
download_url_zones = "https://d37ci6vzurychx.cloudfront.net/misc/taxi+_zone_lookup.csv"
path_zones = f"{path_volume}/taxi_zone_lookup.csv"

dbutils.fs.cp(download_url_zones, path_zones)

df_zones = spark.read.csv(path_zones, header=True, inferSchema=True)
df_zones.show(5)
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 5 rows

# %%
df_trips_zones = df_trips.join(df_zones, df_trips.PULocationID == df_zones.LocationID, "left") \
                         .withColumnRenamed("Borough", "pickup_borough")

df_trips_zones = df_trips_zones.join(df_zones, df_trips.DOLocationID == df_zones.LocationID, "left") \
                               .withColumnRenamed("Borough", "dropoff_borough")

df_trips_zones.show(5)
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+-------------+-----------+-----------+-----------+----------+--------------+--------------------+------------+----------+---------------+--------------------+------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|trip_id|trip_duration|pickup_date|pickup_hour|day_of_week|LocationID|pickup_borough|                Zone|service_zone|LocationID|dropoff_borough|                Zone|service_zone|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+-------------+-----------+-----------+-----------+----------+--------------+--------------------+------------+----------+---------------+--------------------+------------+
# |       1| 2019-01-01 00:46:40|  2019-01-01 00:53:20|            1.0|          1.5|       1.0|                 N|         151|         239|           1|        7.0|  0.5|    0.5|      1.65|         0.0|                  0.3|        9.95|                NULL|       NULL|      0|          400| 2019-01-01|          0|          3|       151|     Manhattan|    Manhattan Valley| Yellow Zone|       239|      Manhattan|Upper West Side S...| Yellow Zone|
# |       1| 2019-01-01 00:59:47|  2019-01-01 01:18:59|            1.0|          2.6|       1.0|                 N|         239|         246|           1|       14.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        16.3|                NULL|       NULL|      1|         1152| 2019-01-01|          0|          3|       239|     Manhattan|Upper West Side S...| Yellow Zone|       246|      Manhattan|West Chelsea/Huds...| Yellow Zone|
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|            3.0|          0.0|       1.0|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                NULL|       NULL|      2|          250| 2018-12-21|         13|          6|       236|     Manhattan|Upper East Side N...| Yellow Zone|       236|      Manhattan|Upper East Side N...| Yellow Zone|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                NULL|       NULL|      3|          200| 2018-11-28|         15|          4|       193|        Queens|Queensbridge/Rave...|   Boro Zone|       193|         Queens|Queensbridge/Rave...|   Boro Zone|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|      4|           96| 2018-11-28|         15|          4|       193|        Queens|Queensbridge/Rave...|   Boro Zone|       193|         Queens|Queensbridge/Rave...|   Boro Zone|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+-------+-------------+-----------+-----------+-----------+----------+--------------+--------------------+------------+----------+---------------+--------------------+------------+
# only showing top 5 rows

# %%
df_trips_zones.groupBy("pickup_borough").agg(count("*").alias("pickup_count")) \
    .orderBy(col("pickup_count").desc()).show(1)

df_trips_zones.groupBy("dropoff_borough").agg(count("*").alias("dropoff_count")) \
    .orderBy(col("dropoff_count").desc()).show(1)
# Out:
# +--------------+------------+
# |pickup_borough|pickup_count|
# +--------------+------------+
# |     Manhattan|     6950965|
# +--------------+------------+
# only showing top 1 row
# +---------------+-------------+
# |dropoff_borough|dropoff_count|
# +---------------+-------------+
# |      Manhattan|      6817355|
# +---------------+-------------+
# only showing top 1 row

# %%
df_trips_zones.groupBy("pickup_borough", "pickup_hour").agg(count("*").alias("trips_count")) \
    .orderBy(col("trips_count").desc()).show(5)
# Out:
# +--------------+-----------+-----------+
# |pickup_borough|pickup_hour|trips_count|
# +--------------+-----------+-----------+
# |     Manhattan|         18|     471539|
# |     Manhattan|         19|     432836|
# |     Manhattan|         17|     426498|
# |     Manhattan|         15|     409119|
# |     Manhattan|         14|     391823|
# +--------------+-----------+-----------+
# only showing top 5 rows

# %%
df_trips_zones.groupBy("pickup_borough", "day_of_week").agg(count("*").alias("trips_count")) \
    .orderBy(col("trips_count").desc()).show(5)
# Out:
# +--------------+-----------+-----------+
# |pickup_borough|day_of_week|trips_count|
# +--------------+-----------+-----------+
# |     Manhattan|          5|    1229554|
# |     Manhattan|          4|    1144782|
# |     Manhattan|          3|    1086202|
# |     Manhattan|          6|     984950|
# |     Manhattan|          7|     927504|
# +--------------+-----------+-----------+
# only showing top 5 rows

# %%
df_trips_zones.groupBy("pickup_borough").agg(avg("trip_distance").alias("avg_distance"),
                                             avg("fare_amount").alias("avg_fare")).show()
# Out:
# +--------------+------------------+------------------+
# |pickup_borough|      avg_distance|          avg_fare|
# +--------------+------------------+------------------+
# |      Brooklyn| 4.787677275447492|18.649132800172286|
# |         Bronx| 7.233194552098303| 26.26890543682963|
# |     Manhattan|2.2286693358402596|10.792468572351568|
# |        Queens|11.283218499361993| 35.14462651722029|
# |           N/A| 3.193850899742941|  59.5731593830335|
# |       Unknown| 2.415464130400774|14.944423051653523|
# | Staten Island|12.503601108033246|45.289861495844896|
# |           EWR| 2.641098654708519| 76.24024663677126|
# +--------------+------------------+------------------+

# %%
df_trips_zones.orderBy(col("fare_amount").desc()).select("trip_id", "fare_amount", "pickup_borough").show(1)
df_trips_zones.orderBy(col("fare_amount").asc()).select("trip_id", "fare_amount", "pickup_borough").show(1)
# Out:
# +-------+-----------+--------------+
# |trip_id|fare_amount|pickup_borough|
# +-------+-----------+--------------+
# |2499655|  623259.86|     Manhattan|
# +-------+-----------+--------------+
# only showing top 1 row
# +-------+-----------+--------------+
# |trip_id|fare_amount|pickup_borough|
# +-------+-----------+--------------+
# |4890649|     -362.0|        Queens|
# +-------+-----------+--------------+
# only showing top 1 row

# %%
file_name_2025 = 'yellow_tripdata_2025-01.parquet'
download_url_2025 = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet'

dbutils.fs.cp(download_url_2025, f"{path_volume}/{file_name_2025}")
df_trips_2025 = spark.read.parquet(f"{path_volume}/{file_name_2025}", header=True, inferSchema=True)

df_trips_2025.select(avg("trip_distance").alias("avg_distance_2025"),
                     avg("fare_amount").alias("avg_fare_2025"),
                     avg("tip_amount").alias("avg_tip_2025")).show()
# Out:
# +-----------------+------------------+------------------+
# |avg_distance_2025|     avg_fare_2025|      avg_tip_2025|
# +-----------------+------------------+------------------+
# |5.855126178844192|17.081802760453556|2.9598127862763484|
# +-----------------+------------------+------------------+

# %% [markdown]
# Part 3:

# %%
df_trips_zones.createOrReplaceTempView("trips_zones")

# %%
# %sql
SELECT trip_id, passenger_count
FROM trips_zones
ORDER BY passenger_count DESC
LIMIT 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trip_id</th><th>passenger_count</th></tr></thead><tbody><tr><td>949956</td><td>9.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT pickup_borough, COUNT(*) as pickup_count
FROM trips_zones
GROUP BY pickup_borough
ORDER BY pickup_count DESC
LIMIT 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_borough</th><th>pickup_count</th></tr></thead><tbody><tr><td>Manhattan</td><td>6950965</td></tr></tbody></table></div>

# %%
# %sql
SELECT CORR(trip_distance, tip_amount) as corr_distance_tip
FROM trips_zones;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>corr_distance_tip</th></tr></thead><tbody><tr><td>0.5269200663652669</td></tr></tbody></table></div>

# %% [markdown]
# Part 4 :

# %%
df_trips.groupBy("pickup_hour").count().orderBy("pickup_hour").display()


df_trips_zones.groupBy("pickup_borough").count().display()


from pyspark.sql.functions import round
df_trips.groupBy("pickup_hour").agg(round(avg("tip_amount"),2).alias("avg_tip")).orderBy("pickup_hour").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_hour</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>207842</td></tr><tr><td>1</td><td>149254</td></tr><tr><td>2</td><td>109421</td></tr><tr><td>3</td><td>78086</td></tr><tr><td>4</td><td>61424</td></tr><tr><td>5</td><td>75533</td></tr><tr><td>6</td><td>178598</td></tr><tr><td>7</td><td>304858</td></tr><tr><td>8</td><td>373742</td></tr><tr><td>9</td><td>365935</td></tr><tr><td>10</td><td>361390</td></tr><tr><td>11</td><td>375441</td></tr><tr><td>12</td><td>401173</td></tr><tr><td>13</td><td>404153</td></tr><tr><td>14</td><td>433139</td></tr><tr><td>15</td><td>452691</td></tr><tr><td>16</td><td>420843</td></tr><tr><td>17</td><td>468479</td></tr><tr><td>18</td><td>515390</td></tr><tr><td>19</td><td>475186</td></tr><tr><td>20</td><td>423156</td></tr><tr><td>21</td><td>409901</td></tr><tr><td>22</td><td>369041</td></tr><tr><td>23</td><td>281941</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_borough</th><th>count</th></tr></thead><tbody><tr><td>Brooklyn</td><td>91905</td></tr><tr><td>Bronx</td><td>18062</td></tr><tr><td>Manhattan</td><td>6950965</td></tr><tr><td>Queens</td><td>471173</td></tr><tr><td>N/A</td><td>3890</td></tr><tr><td>Unknown</td><td>159815</td></tr><tr><td>Staten Island</td><td>361</td></tr><tr><td>EWR</td><td>446</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_hour</th><th>avg_tip</th></tr></thead><tbody><tr><td>0</td><td>1.95</td></tr><tr><td>1</td><td>1.8</td></tr><tr><td>2</td><td>1.68</td></tr><tr><td>3</td><td>1.63</td></tr><tr><td>4</td><td>1.74</td></tr><tr><td>5</td><td>1.96</td></tr><tr><td>6</td><td>1.65</td></tr><tr><td>7</td><td>1.72</td></tr><tr><td>8</td><td>1.78</td></tr><tr><td>9</td><td>1.76</td></tr><tr><td>10</td><td>1.71</td></tr><tr><td>11</td><td>1.66</td></tr><tr><td>12</td><td>1.67</td></tr><tr><td>13</td><td>1.72</td></tr><tr><td>14</td><td>1.75</td></tr><tr><td>15</td><td>1.75</td></tr><tr><td>16</td><td>1.88</td></tr><tr><td>17</td><td>1.84</td></tr><tr><td>18</td><td>1.85</td></tr><tr><td>19</td><td>1.88</td></tr><tr><td>20</td><td>1.95</td></tr><tr><td>21</td><td>2.04</td></tr><tr><td>22</td><td>2.05</td></tr><tr><td>23</td><td>2.02</td></tr></tbody></table></div>
